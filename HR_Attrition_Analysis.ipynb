# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# #Data Exploration

# %%
df_train = pd.read_csv('HR_comma_sep.csv')

# %%
df_train
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
df_train.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df_train['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
sns.boxplot(x='left',y='satisfaction_level',data=df_train)

# %%
sns.violinplot(x='left',y='satisfaction_level',data=df_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# It clearly shows that the stark difference in the satisfaction level of attrited employees and retained employees

# %%
sns.violinplot(x='left',y='last_evaluation',data=df_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Last evaluation shows a bimodal distribution of attrited employees

# %%
sns.barplot(x='left',y='number_project',data=df_train)

# %%
sns.countplot(x='number_project',data=df_train,hue='left')

# %%
sns.countplot(x='time_spend_company',data=df_train,hue='left')

# %%
sns.barplot(x='left',y='time_spend_company',data=df_train)

# %% [markdown]
# Number of Projects vs Number of Years

# %%
sns.barplot(x='time_spend_company',y='number_project',data=df_train,hue='left')

# %%
sns.barplot(y='time_spend_company',x='number_project',data=df_train,hue='left')

# %% [markdown]
# The above plots gives us an indication of some possible reasons of why someone might have left -
#
# For Time spend in the company -
#
# Most who left had spend 3 years and 4 years at the company in decreasing order
#
# 3 Years - Avg. no. of projects - 2 ( 2 less than the people who are retained )
# 4 Years - Avg. no. of projects - 6 ( 2 more than the people who are retained )

# %%
sns.violinplot(x='left',y='average_montly_hours',data=df_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Average Monthly hours shows a bimodal distribution of attrited employees

# %% [markdown]
# Average monthly hours vs Time Spend in the Company

# %%
sns.barplot(x='time_spend_company',y='average_montly_hours',data=df_train,hue='left')

# %% [markdown]
# Baring people who left in the 3rd year, people who left were overworked on an average.

# %% [markdown]
# The plots

# %% [markdown]
# Correlation Matrix for Attrited employees

# %%
pd.DataFrame.corr(df_train[df_train['left']==1])
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.182295       -0.227113
# last_evaluation                  0.182295         1.000000        0.804155
# number_project                  -0.227113         0.804155        1.000000
# average_montly_hours            -0.084117         0.830336        0.875194
# time_spend_company               0.446440         0.783873        0.601989
# Work_accident                    0.005864        -0.001875       -0.008401
# left                                  NaN              NaN             NaN
# promotion_last_5years            0.005516        -0.047992       -0.032301
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.084117            0.446440
# last_evaluation                    0.830336            0.783873
# number_project                     0.875194            0.601989
# ...

# %%
pd.DataFrame.corr(df_train[df_train['left']==0])
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.086357       -0.092799
# last_evaluation                  0.086357         1.000000        0.040306
# number_project                  -0.092799         0.040306        1.000000
# average_montly_hours             0.055354         0.090304        0.070289
# time_spend_company              -0.168791        -0.017682        0.079943
# Work_accident                   -0.003128        -0.007416        0.001098
# left                                  NaN              NaN             NaN
# promotion_last_5years            0.001228        -0.002034        0.001676
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                 0.055354           -0.168791
# last_evaluation                    0.090304           -0.017682
# number_project                     0.070289            0.079943
# ...

# %%
sns.countplot(x='left',data=df_train,hue='Work_accident')

# %%
sns.countplot(x='salary',data=df_train)

# %%
sns.countplot(x='salary',data=df_train,hue='left')

# %%
f, axarr = plt.subplots(1,3,figsize=(20,8))
a = sns.countplot(x='time_spend_company',data=df_train[(df_train['salary']=='low')],hue='left',ax=axarr[0])
b = sns.countplot(x='time_spend_company',data=df_train[(df_train['salary']=='medium')],hue='left',ax=axarr[1])
c = sns.countplot(x='time_spend_company',data=df_train[(df_train['salary']=='high')],hue='left',ax=axarr[2])
plt.show()

# %%
job_profile_vc = df_train['sales'].value_counts()

# %%
job_profile = []

# %%
for i in job_profile_vc.index:
    job_profile.append(i)

# %%
job_profile
# Out:
# ['sales',
#  'technical',
#  'support',
#  'IT',
#  'product_mng',
#  'marketing',
#  'RandD',
#  'accounting',
#  'hr',
#  'management']

# %%
sns.countplot(y='sales',data=df_train)

# %%
sns.countplot(y='sales',data=df_train,hue='left')

# %%
job_profile_based_attrition_percent = []

# %%
df_train[(df_train['left'] == 1) & (df_train['sales']==i)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
for i in job_profile:
    jb = round(len(df_train[(df_train['sales']==i)])/len(df_train),2)
    jb_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['sales']==i)])/len(df_train[(df_train['sales']==i)]),2)
    jb_total_left_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['sales']==i)])/len(df_train[(df_train['left']==1)]),2)
#     jb_total_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['sales']==i)])/len(df_train),3)
    tup = (i,jb,jb_pct,jb_total_left_pct)
    job_profile_based_attrition_percent.append(tup)

# %%
job_profile_based_attrition_percent
# Out:
# [('sales', 0.28, 0.24, 0.28),
#  ('technical', 0.18, 0.26, 0.2),
#  ('support', 0.15, 0.25, 0.16),
#  ('IT', 0.08, 0.22, 0.08),
#  ('product_mng', 0.06, 0.22, 0.06),
#  ('marketing', 0.06, 0.24, 0.06),
#  ('RandD', 0.05, 0.15, 0.03),
#  ('accounting', 0.05, 0.27, 0.06),
#  ('hr', 0.05, 0.29, 0.06),
#  ('management', 0.04, 0.14, 0.03)]

# %% [markdown]
# The above list contains tuples containing percentage of attrited employees based on job profile.

# %%
sns.countplot(y='sales',data=df_train,hue='salary')

# %%
salary_vc = df_train['salary'].value_counts()

# %%
salary_list= []

# %%
for i in salary_vc.index:
    salary_list.append(i)

# %%
salary_attrition_list = []

# %%
salary_attrition_list.append(['salary_slab','total_percent','internal_attrition_percent','total_attrition_percent'])

# %%
for i in salary_list:
    jb = round(len(df_train[(df_train['salary']==i)])/len(df_train),2)
    jb_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['salary']==i)])/len(df_train[(df_train['salary']==i)]),2)
    jb_total_left_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['salary']==i)])/len(df_train[(df_train['left']==1)]),2)
#     jb_total_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['sales']==i)])/len(df_train),3)
    l = [i,jb,jb_pct,jb_total_left_pct]
    salary_attrition_list.append(l)

# %%
salary_attrition_list
# Out:
# [['salary_slab',
#   'total_percent',
#   'internal_attrition_percent',
#   'total_attrition_percent'],
#  ['low', 0.49, 0.3, 0.61],
#  ['medium', 0.43, 0.2, 0.37],
#  ['high', 0.08, 0.07, 0.02]]

# %%
round(len(df_train[(df_train['left'] == 1)])/len(df_train),2)
# Out:
# 0.24

# %% [markdown]
# As expected salary plays a huge factor in attrition - Low salaried employees have attrition rate 0.3 > 0.24 (average)

# %%
salary_job_based_attrition_list = []

# %%
salary_job_based_attrition_list.append(['salary_slab','job_profile','job_profile_based_attrition','job_profile_based_total_attrition'])

# %%
for i in salary_list:
    for j in job_profile:
        
#         jb = round(len(df_train[(df_train['salary']==i)])/len(df_train),2)
        jb_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['salary']==i)&(df_train['sales']==j)])/len(df_train[(df_train['salary']==i)&(df_train['sales']==j)]),2)
        jb_total_left_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['salary']==i)&(df_train['sales']==j)])/len(df_train[(df_train['left']==1)
                                                                                                               &(df_train['salary']==i)]),2)
    #     jb_total_pct = round(len(df_train[(df_train['left'] == 1) & (df_train['sales']==i)])/len(df_train),3)
        l = [i,j,jb_pct,jb_total_left_pct]
        salary_job_based_attrition_list.append(l)

# %%
salary_job_based_attrition_list
# Out:
# [['salary_slab',
#   'job_profile',
#   'job_profile_based_attrition',
#   'job_profile_based_total_attrition'],
#  ['low', 'sales', 0.33, 0.32],
#  ['low', 'technical', 0.28, 0.17],
#  ['low', 'support', 0.34, 0.18],
#  ['low', 'IT', 0.28, 0.08],
#  ['low', 'product_mng', 0.23, 0.05],
#  ['low', 'marketing', 0.31, 0.06],
#  ['low', 'RandD', 0.15, 0.03],
#  ['low', 'accounting', 0.28, 0.05],
#  ['low', 'hr', 0.27, 0.04],
#  ['low', 'management', 0.33, 0.03],
#  ['medium', 'sales', 0.17, 0.23],
#  ['medium', 'technical', 0.26, 0.22],
#  ['medium', 'support', 0.17, 0.12],
#  ['medium', 'IT', 0.18, 0.07],
#  ['medium', 'product_mng', 0.23, 0.07],
#  ['medium', 'marketing', 0.18, 0.05],
#  ['medium', 'RandD', 0.17, 0.05],
#  ['medium', 'accounting', 0.3, 0.08],
#  ['medium', 'hr', 0.33, 0.09],
#  ['medium', 'management', 0.14, 0.02],
#  ['high', 'sales', 0.05, 0.17],
#  ['high', 'technical', 0.12, 0.3],
#  ['high', 'support', 0.06, 0.1],
#  ['high', 'IT', 0.05, 0.05],
# ...

# %% [markdown]
# Sales, Support, Marketing, Mgmt - Attrition rate drops from 33% to 17% when comparing low salary band to medium salary band.
#
# Technical, HR - Attrition rate is consistent and is on the higher side for all three slabs.
#
# IT - Drops from 28 to 18
#
# Product_mng, Accounting - Same attrition rate in both bands.
#
# RandD - Attrition rate is more or less same for both salary bands and it is on the lower side.

# %%
sns.countplot(x='time_spend_company',data=df_train,hue='salary')

# %%
sns.countplot(x='salary',data=df_train,hue='time_spend_company')

# %%
df_train.sort(columns=['satisfaction_level'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        satisfaction_level  last_evaluation  number_project  \
# 14484                0.09             0.96               6
# 1873                 0.09             0.93               6
# 340                  0.09             0.89               7
# 1882                 0.09             0.89               6
# 332                  0.09             0.98               6
# 12765                0.09             0.87               3
# 12761                0.09             0.93               6
# 350                  0.09             0.80               6
# 761                  0.09             0.93               6
# 14489                0.09             0.78               6
# 765                  0.09             0.87               3
# ...

# %%
df_train_s = df_train[(df_train['satisfaction_level'] > 0.5) & (df_train['left'] == 1)]

# %%
sns.countplot(y='sales',data=df_train_s,hue='salary')

# %%
df_train_s.sort(columns=['satisfaction_level'], ascending=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        satisfaction_level  last_evaluation  number_project  \
# 12231                0.92             0.99               5
# 191                  0.92             0.87               4
# 12007                0.92             0.85               5
# 976                  0.92             0.94               5
# 14442                0.92             0.99               5
# 14402                0.92             0.87               4
# 940                  0.92             0.92               4
# 403                  0.92             0.93               5
# 908                  0.92             1.00               5
# 14614                0.92             0.93               5
# 1979                 0.92             0.82               5
# ...

# %%
np.average(df_train['average_montly_hours'])
# Out:
# 201.05033668911261

# %%
np.average(df_train_s['average_montly_hours'])
# Out:
# 241.20274240940256

# %%
df_train_l_s = df_train[(df_train['satisfaction_level'] < 0.5) & (df_train['left'] == 1)]

# %%
np.average(df_train_l_s['average_montly_hours'])
# Out:
# 193.94660384766391

# %%
df_train_l_1 = df_train[(df_train['left'] == 1)]

# %%
df_train_l_0 = df_train[(df_train['left'] == 0)]

# %% [markdown]
# Since Last evaulation also shows bimodal distribution there can be potentially two types of people who have left.

# %%
df_train_le_h = df_train[(df_train['last_evaluation'] > 0.5) & (df_train['left'] == 1)]

# %%
df_train_le_l = df_train[(df_train['last_evaluation'] < 0.5) & (df_train['left'] == 1)]

# %%
f, axarr = plt.subplots(1,3,figsize=(20,8))
a = sns.countplot(x='number_project',data=df_train_l_1,ax=axarr[0])
# a.set(xlabel='total_left')
a.set(title='total_left')
b = sns.countplot(x='number_project',data=df_train_s,ax=axarr[1])
# b.set(xlabel='left_satisfied')
b.set(title='left_satisfied')

c = sns.countplot(x='number_project',data=df_train_l_s,ax=axarr[2])
# c.set(xlabel='left_less_satisfied')
c.set(title='left_less_satisfied')

plt.show()

# %% [markdown]
# One of the reasons we can infer from the above graphs is that people who left and were less satisfied is because of less number of projects.

# %%
salary_no_hours_list = []

# %%
salary_no_hours_list.append(['salary_slab','avg_m_h_total','avg_m_h_retained','avg_m_h_left','avg_m_h_left_satisfied','avg_m_h_left_less_satisfied'])

# %%
for i in salary_list:
    avg_m_h_total = round(np.average(df_train[(df_train['salary']==i)]['average_montly_hours']))
    avg_m_h_retained = round(np.average(df_train_l_0[(df_train_l_0['salary']==i)]['average_montly_hours']))
    avg_m_h_left = round(np.average(df_train_l_1[(df_train_l_1['salary']==i)]['average_montly_hours']))
    avg_m_h_left_satisfied = round(np.average(df_train_s[(df_train_s['salary']==i)]['average_montly_hours']))
    avg_m_h_left_less_satisfied = round(np.average(df_train_l_s[(df_train_l_s['salary']==i)]['average_montly_hours']))
    l = [i,avg_m_h_total,avg_m_h_retained,avg_m_h_left,avg_m_h_left_satisfied,avg_m_h_left_less_satisfied]
    salary_no_hours_list.append(l)

# %%
salary_no_hours_list
# Out:
# [['salary_slab',
#   'avg_m_h_total',
#   'avg_m_h_retained',
#   'avg_m_h_left',
#   'avg_m_h_left_satisfied',
#   'avg_m_h_left_less_satisfied'],
#  ['low', 201.0, 199.0, 207.0, 240.0, 193.0],
#  ['medium', 201.0, 199.0, 210.0, 243.0, 196.0],
#  ['high', 200.0, 200.0, 193.0, 235.0, 181.0]]

# %%
f, axarr = plt.subplots(1,3,figsize=(20,8))
a = sns.countplot(x='time_spend_company',data=df_train[(df_train['time_spend_company'] < 7)],ax=axarr[0])
a.set(title='Total')

b = sns.countplot(x='time_spend_company',data=df_train_l_0[(df_train_l_0['time_spend_company'] < 7)],ax=axarr[1])
b.set(title='Retained')

c = sns.countplot(x='time_spend_company',data=df_train_l_1,ax=axarr[2])
c.set(title='Left')

plt.show()

# %%
f, axarr = plt.subplots(1,3,figsize=(20,8))
a = sns.countplot(x='time_spend_company',data=df_train_l_1,ax=axarr[0])
# a.set(xlabel='total_left')
a.set(title='total_left')
b = sns.countplot(x='time_spend_company',data=df_train_s,ax=axarr[1])
# b.set(xlabel='left_satisfied')
b.set(title='left_satisfied')

c = sns.countplot(x='time_spend_company',data=df_train_l_s,ax=axarr[2])
# c.set(xlabel='left_less_satisfied')
c.set(title='left_less_satisfied')

plt.show()

# %%
time_spend_company_value_list = []

# %%
time_spend_company_vc = df_train['time_spend_company'].value_counts()

# %%
for i in time_spend_company_vc.index:
    time_spend_company_value_list.append(i)

# %%
time_spend_no_avg_hours_list = []

# %%
time_spend_no_avg_hours_list.append(['time_spend_company','avg_m_h_total','avg_m_h_retained','avg_m_h_left','avg_m_h_left_satisfied','avg_m_h_left_less_satisfied'])

# %%
for i in time_spend_company_value_list:
    avg_m_h_total = round(np.average(df_train[(df_train['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_retained = round(np.average(df_train_l_0[(df_train_l_0['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_left = round(np.average(df_train_l_1[(df_train_l_1['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_left_satisfied = round(np.average(df_train_s[(df_train_s['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_left_less_satisfied = round(np.average(df_train_l_s[(df_train_l_s['time_spend_company']==i)]['average_montly_hours']))
    l = [i,avg_m_h_total,avg_m_h_retained,avg_m_h_left,avg_m_h_left_satisfied,avg_m_h_left_less_satisfied]
    time_spend_no_avg_hours_list.append(l)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
time_spend_no_avg_hours_list
# Out:
# [['time_spend_company',
#   'avg_m_h_total',
#   'avg_m_h_retained',
#   'avg_m_h_left',
#   'avg_m_h_left_satisfied',
#   'avg_m_h_left_less_satisfied'],
#  [3, 187.0, 199.0, 147.0, 219.0, 146.0],
#  [2, 200.0, 200.0, 211.0, 223.0, 195.0],
#  [4, 223.0, 199.0, 270.0, 207.0, 273.0],
#  [5, 223.0, 193.0, 246.0, 244.0, 258.0],
#  [6, 212.0, 200.0, 242.0, 245.0, 168.0],
#  [10, 199.0, 199.0, nan, nan, nan],
#  [7, 201.0, 201.0, nan, nan, nan],
#  [8, 194.0, 194.0, nan, nan, nan]]

# %%
df_tsc = pd.DataFrame(data=time_spend_no_avg_hours_list[1:],columns=time_spend_no_avg_hours_list[0])

# %%
df_tsc.sort(columns=['time_spend_company'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    time_spend_company  avg_m_h_total  avg_m_h_retained  avg_m_h_left  \
# 1                   2            200               200           211
# 0                   3            187               199           147
# 2                   4            223               199           270
# 3                   5            223               193           246
# 4                   6            212               200           242
# 6                   7            201               201           NaN
# 7                   8            194               194           NaN
# 5                  10            199               199           NaN
#
#    avg_m_h_left_satisfied  avg_m_h_left_less_satisfied
# 1                     223                          195
# ...

# %% [markdown]
# For Employees who left and were satisfied a large chunk of them have spent 5-6 years in the company. Average work load of these employees is greater than the total average

# %% [markdown]
# Last Evaluation

# %%
f, axarr = plt.subplots(1,3,figsize=(20,8))
a = sns.countplot(x='time_spend_company',data=df_train_l_1,ax=axarr[0])
# a.set(xlabel='total_left')
a.set(title='total_left')
b = sns.countplot(x='time_spend_company',data=df_train_le_h,ax=axarr[1])
# b.set(xlabel='left_satisfied')
b.set(title='left_high_evaluation')

c = sns.countplot(x='time_spend_company',data=df_train_le_l,ax=axarr[2])
# c.set(xlabel='left_less_satisfied')
c.set(title='left_low_evaluation')

plt.show()

# %%
time_spend_no_avg_hours_list_le = []

# %%
time_spend_no_avg_hours_list_le.append(['time_spend_company','avg_m_h_total','avg_m_h_retained','avg_m_h_left','avg_m_h_high_evaluation','avg_m_h_left_low_evaluation'])

# %%
for i in time_spend_company_value_list:
    avg_m_h_total = round(np.average(df_train[(df_train['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_retained = round(np.average(df_train_l_0[(df_train_l_0['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_left = round(np.average(df_train_l_1[(df_train_l_1['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_high_evaluation = round(np.average(df_train_le_h[(df_train_le_h['time_spend_company']==i)]['average_montly_hours']))
    avg_m_h_left_low_evaluation = round(np.average(df_train_le_l[(df_train_le_l['time_spend_company']==i)]['average_montly_hours']))
    l = [i,avg_m_h_total,avg_m_h_retained,avg_m_h_left,avg_m_h_high_evaluation,avg_m_h_left_low_evaluation]
    time_spend_no_avg_hours_list_le.append(l)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
df_tsc_le = pd.DataFrame(data=time_spend_no_avg_hours_list_le[1:],columns=time_spend_no_avg_hours_list_le[0])

# %%
df_tsc_le.sort(columns=['time_spend_company'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    time_spend_company  avg_m_h_total  avg_m_h_retained  avg_m_h_left  \
# 1                   2            200               200           211
# 0                   3            187               199           147
# 2                   4            223               199           270
# 3                   5            223               193           246
# 4                   6            212               200           242
# 6                   7            201               201           NaN
# 7                   8            194               194           NaN
# 5                  10            199               199           NaN
#
#    avg_m_h_high_evaluation  avg_m_h_left_low_evaluation
# 1                      214                          177
# ...

# %%
plt.scatter(df_train_l_1['satisfaction_level'],df_train_l_1['last_evaluation'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
plt.scatter(df_train_l_s['satisfaction_level'],df_train_l_s['last_evaluation'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
plt.scatter(df_train_s['satisfaction_level'],df_train_s['last_evaluation'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# People who left in year 4 had high last evaluation but low satisfaction. Potential reasons could be high workload as indicated from the above table.

# %% [markdown]
# People who left in year 3 had low satisfaction and consisted of people from both sections - high evaluation and low evaluation. Low evaluation might indicated they were fired. High evaluation might indicate they didnt have enough opportunities considering low workload from above table.

# %% [markdown]
# People who left in year 5 and 6 had high satisfaction and high evaluation. Indicating no potential reason of the company firing them. They willingly left the company to pursue better opportunities is one the reasons.

# %%
number_of_projects_list = []

# %%
number_of_projects_vc = df_train['number_project'].value_counts()

# %%
for i in number_of_projects_vc.index:
    number_of_projects_list.append(i)

# %%
time_spend_vs_number_of_projects_list = []

# %%
time_spend_vs_number_of_projects_list.append(['time_spend','average_no_projects_agg','avg_no_project_retained','avg_no_project_left','avg_no_project_left_satisfied',
                                              'avg_no_project_left_less_satisfied'])

# %%
for i in time_spend_company_value_list:
    avg_no_project_agg = round(np.average(df_train[(df_train['time_spend_company']==i)]['number_project']),2)
    avg_no_project_retained = round(np.average(df_train_l_0[(df_train_l_0['time_spend_company']==i)]['number_project']),2)
    avg_no_project_left = round(np.average(df_train_l_1[(df_train_l_1['time_spend_company']==i)]['number_project']),2)
    avg_no_project_left_satisfied = round(np.average(df_train_s[(df_train_s['time_spend_company']==i)]['number_project']),2)
    avg_no_project_left_less_satisfied = round(np.average(df_train_l_s[(df_train_l_s['time_spend_company']==i)]['number_project']),2)
    l = [i,avg_no_project_agg,avg_no_project_retained,avg_no_project_left,avg_no_project_left_satisfied,avg_no_project_left_less_satisfied]
    time_spend_vs_number_of_projects_list.append(l)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
time_spend_vs_number_of_projects_list
# Out:
# [['time_spend',
#   'average_no_projects_agg',
#   'avg_no_project_retained',
#   'avg_no_project_left',
#   'avg_no_project_left_satisfied',
#   'avg_no_project_left_less_satisfied'],
#  [3,
#   3.3300000000000001,
#   3.73,
#   2.1000000000000001,
#   3.5899999999999999,
#   2.0600000000000001],
#  [2,
#   3.6899999999999999,
#   3.6800000000000002,
#   4.0599999999999996,
#   4.0300000000000002,
#   4.0899999999999999],
#  [4,
#   4.6299999999999999,
#   3.9199999999999999,
#   5.96,
#   4.1900000000000004,
#   6.0599999999999996],
#  [5, 4.5199999999999996, 4.21, 4.7599999999999998, 4.5499999999999998, 5.96],
#  [6,
#   4.21,
#   4.0599999999999996,
#   4.5700000000000003,
#   4.5700000000000003,
#   4.6200000000000001],
#  [10, 3.6800000000000002, 3.6800000000000002, nan, nan, nan],
#  [7, 3.8500000000000001, 3.8500000000000001, nan, nan, nan],
#  [8, 3.7799999999999998, 3.7799999999999998, nan, nan, nan]]

# %%
df_tsc_np = pd.DataFrame(data=time_spend_vs_number_of_projects_list[1:],columns=time_spend_vs_number_of_projects_list[0])

# %%
df_tsc_np.sort(columns=['time_spend'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    time_spend  average_no_projects_agg  avg_no_project_retained  \
# 1           2                     3.69                     3.68
# 0           3                     3.33                     3.73
# 2           4                     4.63                     3.92
# 3           5                     4.52                     4.21
# 4           6                     4.21                     4.06
# 6           7                     3.85                     3.85
# 7           8                     3.78                     3.78
# 5          10                     3.68                     3.68
#
#    avg_no_project_left  avg_no_project_left_satisfied  \
# 1                 4.06                           4.03
# 0                 2.10                           3.59
# ...

# %%
sns.countplot(x='salary',data=df_train_le_h[(df_train_le_h['time_spend_company']==4)])

# %%
sns.countplot(y='sales',data=df_train_le_h[(df_train_le_h['time_spend_company']==4)])

# %%
sns.countplot(x='salary',data=df_train_le_h[(df_train_le_h['time_spend_company']==5)|(df_train_le_h['time_spend_company']==6)])

# %%
sns.countplot(y='sales',data=df_train_le_h[(df_train_le_h['time_spend_company']==5)|(df_train_le_h['time_spend_company']==6)])

# %%
sns.countplot(x='time_spend_company',data=df_train_l_s,hue='salary')

# %%
sns.countplot(x='number_project',data=df_train_l_1,hue='sales')

# %% [markdown]
# #Clustering

# %%
from kmodes import kprototypes

# %%
X_target = df_train['left']

# %%
X_train = df_train

# %%
X_train
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
kproto = kprototypes.KPrototypes(n_clusters=4, init='Cao', verbose=2)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.

# %%
clusters = kproto.fit_predict(X_train, categorical=[5,6,7,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-269-345b405bf681> in <module>()
# ----> 1 clusters = kproto.fit_predict(X_train, categorical=[5,6,7,8])
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/kmodes/kmodes.py in fit_predict(self, X, y, **kwargs)
#     372         predict(X).
#     373         """
# --> 374         return self.fit(X, **kwargs).labels_
#     375
#     376     def predict(self, X, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/kmodes/kprototypes.py in fit(self, X, y, categorical)
#     413                                                     self.init,
#     414                                                     self.n_init,
# --> 415                                                     self.verbose)
#     416         return self
#     417
#
# ...

# %%
X_train_1 = X_train.as_matrix()

# %%
X_train_1
# Out:
# array([[0.38, 0.53, 2, ..., 0, 'sales', 'low'],
#        [0.8, 0.86, 5, ..., 0, 'sales', 'medium'],
#        [0.11, 0.88, 7, ..., 0, 'sales', 'medium'],
#        ...,
#        [0.37, 0.53, 2, ..., 0, 'support', 'low'],
#        [0.11, 0.96, 6, ..., 0, 'support', 'low'],
#        [0.37, 0.52, 2, ..., 0, 'support', 'low']], dtype=object)

# %%
X_train_1.shape
# Out:
# (14999, 9)

# %%
clusters = kproto.fit_predict(X_train_1, categorical=[5,6,7,8])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 501, ncost: 3744710.0934094423
# Run: 1, iteration: 2/100, moves: 381, ncost: 3725797.21726541
# Run: 1, iteration: 3/100, moves: 346, ncost: 3708936.61245926
# Run: 1, iteration: 4/100, moves: 310, ncost: 3694808.4379657214
# Run: 1, iteration: 5/100, moves: 262, ncost: 3683675.1758988
# Run: 1, iteration: 6/100, moves: 261, ncost: 3675291.491657296
# Run: 1, iteration: 7/100, moves: 282, ncost: 3665124.2296754997
# Run: 1, iteration: 8/100, moves: 188, ncost: 3657841.674377687
# Run: 1, iteration: 9/100, moves: 112, ncost: 3655605.9714043164
# Run: 1, iteration: 10/100, moves: 0, ncost: 3655605.9714043164

# %% [markdown]
# Feature Scaling ( Numerical Features )

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train = StandardScaler?

# %%
X_train_Scaler = StandardScaler()

# %%
X_train_2 = X_train.filter(items=['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company'])

# %%
X_train_2 = X_train_Scaler.fit_transform(X_train_2)

# %%
X_train_2
# Out:
# array([[-0.93649469, -1.08727529, -1.46286291, -0.88203988, -0.34123516],
#        [ 0.75281433,  0.84070693,  0.97111292,  1.22042276,  1.71343614],
#        [-2.02247906,  0.95755433,  2.59376348,  1.4206573 ,  0.34365527],
#        ...,
#        [-0.97671633, -1.08727529, -1.46286291, -1.16236823, -0.34123516],
#        [-2.02247906,  1.42494396,  1.7824382 ,  1.58084493,  0.34365527],
#        [-0.97671633, -1.14569899, -1.46286291, -0.86201642, -0.34123516]])

# %%
X_train_3 = X_train_Scaler.fit_transform(X_train[['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company']])

# %%
X_train_3
# Out:
# array([[-0.93649469, -1.08727529, -1.46286291, -0.88203988, -0.34123516],
#        [ 0.75281433,  0.84070693,  0.97111292,  1.22042276,  1.71343614],
#        [-2.02247906,  0.95755433,  2.59376348,  1.4206573 ,  0.34365527],
#        ...,
#        [-0.97671633, -1.08727529, -1.46286291, -1.16236823, -0.34123516],
#        [-2.02247906,  1.42494396,  1.7824382 ,  1.58084493,  0.34365527],
#        [-0.97671633, -1.14569899, -1.46286291, -0.86201642, -0.34123516]])

# %%
X_Categorical = X_train[['Work_accident','promotion_last_5years','sales','salary']]

# %%
X_Categorical
# Out:
#        Work_accident  promotion_last_5years       sales  salary
# 0                  0                      0       sales     low
# 1                  0                      0       sales  medium
# 2                  0                      0       sales  medium
# 3                  0                      0       sales     low
# 4                  0                      0       sales     low
# 5                  0                      0       sales     low
# 6                  0                      0       sales     low
# 7                  0                      0       sales     low
# 8                  0                      0       sales     low
# 9                  0                      0       sales     low
# 10                 0                      0       sales     low
# 11                 0                      0       sales     low
# 12                 0                      0       sales     low
# 13                 0                      0       sales     low
# ...

# %%
X_Categorical_Matrix = X_Categorical.as_matrix()

# %%
X_Categorical_Matrix
# Out:
# array([[0, 0, 'sales', 'low'],
#        [0, 0, 'sales', 'medium'],
#        [0, 0, 'sales', 'medium'],
#        ...,
#        [0, 0, 'support', 'low'],
#        [0, 0, 'support', 'low'],
#        [0, 0, 'support', 'low']], dtype=object)

# %%
X_train_4 = np.concatenate((X_train_2,X_Categorical_Matrix),axis=1)

# %%
X_train_4
# Out:
# array([[-0.9364946890660525, -1.0872752890605568, -1.4628629148312604, ...,
#         0, 'sales', 'low'],
#        [0.7528143315270648, 0.840706927367526, 0.9711129237526113, ..., 0,
#         'sales', 'medium'],
#        [-2.0224790594473423, 0.9575543344237735, 2.5937634828085256, ...,
#         0, 'sales', 'medium'],
#        ...,
#        [-0.9767163324135077, -1.0872752890605568, -1.4628629148312604, ...,
#         0, 'support', 'low'],
#        [-2.0224790594473423, 1.424943962648763, 1.7824382032805686, ..., 0,
#         'support', 'low'],
#        [-0.9767163324135077, -1.1456989925886807, -1.4628629148312604, ...,
#         0, 'support', 'low']], dtype=object)

# %%
kproto_1 = kprototypes.KPrototypes(n_clusters=4, init='Cao', verbose=2)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.

# %%
clusters_1 = kproto_1.fit_predict(X_train_4, categorical=[5,6,7,8])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 3891, ncost: 52210.80442121007
# Run: 1, iteration: 2/100, moves: 1850, ncost: 51160.034821885914
# Run: 1, iteration: 3/100, moves: 891, ncost: 50793.55282578187
# Run: 1, iteration: 4/100, moves: 660, ncost: 50450.24111755832
# Run: 1, iteration: 5/100, moves: 677, ncost: 49946.35576936705
# Run: 1, iteration: 6/100, moves: 506, ncost: 49777.39544926659
# Run: 1, iteration: 7/100, moves: 187, ncost: 49763.094988472905
# Run: 1, iteration: 8/100, moves: 87, ncost: 49759.313672888784
# Run: 1, iteration: 9/100, moves: 39, ncost: 49758.69627692356
# Run: 1, iteration: 10/100, moves: 12, ncost: 49758.61216561906
# Run: 1, iteration: 11/100, moves: 1, ncost: 49758.610168414954
# Run: 1, iteration: 12/100, moves: 0, ncost: 49758.610168414954

# %%
kproto_1.labels_
# Out:
# array([1, 3, 0, ..., 1, 0, 1], dtype=uint8)

# %%
kproto_1.labels_.shape
# Out:
# (14999,)

# %%
cluster_series = pd.DataFrame(data=kproto_1.labels_,columns=['Cluster'])

# %%
cluster_series
# Out:
#        Cluster
# 0            1
# 1            3
# 2            0
# 3            2
# 4            1
# 5            1
# 6            0
# 7            2
# 8            2
# 9            1
# 10           1
# 11           0
# 12           2
# 13           1
# 14           1
# 15           1
# 16           1
# 17           3
# 18           1
# 19           2
# 20           0
# 21           1
# 22           0
# 23           1
# 24           1
# 25           2
# 26           2
# 27           1
# 28           1
# 29           1
# ...        ...
# 14969        1
# 14970        2
# 14971        1
# 14972        0
# 14973        1
# 14974        1
# 14975        0
# 14976        1
# 14977        3
# 14978        1
# 14979        0
# 14980        2
# 14981        2
# 14982        1
# 14983        2
# 14984        1
# 14985        2
# 14986        3
# 14987        2
# 14988        1
# 14989        1
# 14990        2
# 14991        0
# 14992        1
# 14993        3
# 14994        1
# ...

# %%
X_target_with_cluster = pd.concat([X_target,cluster_series],axis=1)

# %%
X_target_with_cluster
# Out:
#        left  Cluster
# 0         1        1
# 1         1        3
# 2         1        0
# 3         1        2
# 4         1        1
# 5         1        1
# 6         1        0
# 7         1        2
# 8         1        2
# 9         1        1
# 10        1        1
# 11        1        0
# 12        1        2
# 13        1        1
# 14        1        1
# 15        1        1
# 16        1        1
# 17        1        3
# 18        1        1
# 19        1        2
# 20        1        0
# 21        1        1
# 22        1        0
# 23        1        1
# 24        1        1
# 25        1        2
# 26        1        2
# 27        1        1
# 28        1        1
# 29        1        1
# ...     ...      ...
# 14969     1        1
# 14970     1        2
# 14971     1        1
# 14972     1        0
# 14973     1        1
# 14974     1        1
# 14975     1        0
# 14976     1        1
# 14977     1        3
# 14978     1        1
# 14979     1        0
# ...

# %%
sns.countplot(x='Cluster',data=X_target_with_cluster)

# %%
sns.countplot(x='Cluster',data=X_target_with_cluster,hue='left')

# %%
X_train.columns.tolist()
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'promotion_last_5years',
#  'sales',
#  'salary']

# %%
X_train_4
# Out:
# array([[-0.9364946890660525, -1.0872752890605568, -1.4628629148312604, ...,
#         0, 'sales', 'low'],
#        [0.7528143315270648, 0.840706927367526, 0.9711129237526113, ..., 0,
#         'sales', 'medium'],
#        [-2.0224790594473423, 0.9575543344237735, 2.5937634828085256, ...,
#         0, 'sales', 'medium'],
#        ...,
#        [-0.9767163324135077, -1.0872752890605568, -1.4628629148312604, ...,
#         0, 'support', 'low'],
#        [-2.0224790594473423, 1.424943962648763, 1.7824382032805686, ..., 0,
#         'support', 'low'],
#        [-0.9767163324135077, -1.1456989925886807, -1.4628629148312604, ...,
#         0, 'support', 'low']], dtype=object)

# %%
df_train_scaled = pd.DataFrame(X_train_4,columns=X_train.columns.tolist())

# %%
df_train_scaled
# Out:
#       satisfaction_level last_evaluation number_project average_montly_hours  \
# 0              -0.936495        -1.08728       -1.46286             -0.88204
# 1               0.752814        0.840707       0.971113              1.22042
# 2               -2.02248        0.957554        2.59376              1.42066
# 3               0.431041        0.899131       0.971113             0.439508
# 4              -0.976716         -1.1457       -1.46286            -0.841993
# 5               -0.81583        -1.26255       -1.46286            -0.962134
# 6                -2.0627        0.314894        1.78244             0.920071
# 7                1.23547        0.782283       0.971113              1.16035
# 8                1.11481         1.65864       0.971113             0.459532
# 9              -0.775608        -1.08728       -1.46286             -1.18239
# 10             -0.654943        -1.02885       -1.46286             -1.32256
# ...

# %%
df_train_scaled_with_left_and_cluster = pd.concat([df_train_scaled,X_target_with_cluster],axis=1)

# %%
df_train_scaled_with_left_and_cluster.to_csv('df_train_scaled_with_left_and_cluster.csv',index=False)

# %%
df_train_new = pd.concat([X_train,X_target_with_cluster],axis=1)

# %%
df_train_new
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
df_train_new.to_csv('df_train_new_with_cluster.csv',index=False)

# %%
sns.barplot(x='Cluster',y='average_montly_hours',data=df_train_new)

# %%
sns.barplot(x='Cluster',y='time_spend_company',data=df_train_new)

# %%
sns.countplot(hue='Cluster',x='time_spend_company',data=df_train_new)

# %%
sns.barplot(x='Cluster',y='satisfaction_level',data=df_train_new)

# %%
sns.barplot(x='Cluster',y='last_evaluation',data=df_train_new)

# %% [markdown]
# #Cluster 0

# %%
sns.violinplot(x='left',y='satisfaction_level',data=df_train_new[df_train_new['Cluster']==0])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.countplot(x='time_spend_company',data=df_train_new[df_train_new['Cluster']==0],hue='left')

# %%
sns.violinplot(x='left',y='satisfaction_level',data=df_train_new[(df_train_new['Cluster']==0)&(df_train_new['time_spend_company']==5)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='last_evaluation',data=df_train_new[(df_train_new['Cluster']==0)&(df_train_new['time_spend_company']==5)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='average_montly_hours',data=df_train_new[(df_train_new['Cluster']==0)&(df_train_new['time_spend_company']==4)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Cluster 0 resembles - Low Satisfaction, High Last evaluation. Reasons for attrition potential high workload.

# %%
Potential_Exits_0 = df_train_new[(df_train_new['Cluster'] == 0)&(df_train_new['average_montly_hours']>240)&(df_train_new['left']==0)&(df_train_new['satisfaction_level']<0.25)]

# %%
Potential_Exits_0
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2086                 0.12             0.87               4
# 2104                 0.17             0.73               5
# 2206                 0.16             0.98               5
# 2250                 0.16             0.90               5
# 2370                 0.12             0.55               5
# 2405                 0.18             0.75               3
# 2420                 0.15             0.51               6
# 2441                 0.22             0.55               4
# 2482                 0.21             0.50               5
# 2546                 0.18             0.67               5
# 2568                 0.21             0.90               4
# 2794                 0.13             0.89               4
# 2824                 0.20             0.89               6
# 2972                 0.22             0.80               4
# 3038                 0.12             0.78               6
# ...

# %% [markdown]
# #Cluster 1

# %%
sns.countplot(x='time_spend_company',data=df_train_new[df_train_new['Cluster']==1],hue='left')

# %%
sns.violinplot(x='left',y='satisfaction_level',data=df_train_new[df_train_new['Cluster']==1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='last_evaluation',data=df_train_new[df_train_new['Cluster']==1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.countplot(x='time_spend_company',data=df_train_new[df_train_new['Cluster']==1],hue='left')

# %%
sns.violinplot(x='left',y='average_montly_hours',data=df_train_new[(df_train_new['Cluster']==1)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.barplot(y='average_montly_hours',data=df_train_new[(df_train_new['Cluster']==1)],x='time_spend_company',hue='left')

# %%
sns.violinplot(x='left',y='average_montly_hours',data=df_train_new[(df_train_new['Cluster']==1)&(df_train_new['time_spend_company']==3)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='satisfaction_level',data=df_train_new[(df_train_new['Cluster']==1)&(df_train_new['time_spend_company']==3)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='last_evaluation',data=df_train_new[(df_train_new['Cluster']==1)&(df_train_new['time_spend_company']==3)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='number_project',data=df_train_new[(df_train_new['Cluster']==1)&(df_train_new['time_spend_company']==3)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Cluster 1 resembles - Low Satisfaction, Low evaluation due to low working hours.

# %%
Potential_Exits_1 = df_train_new[(df_train_new['Cluster']==1)&(df_train_new['time_spend_company']==3)&(df_train_new['number_project']==2)&
                                (df_train_new['average_montly_hours']<150)&(df_train_new['left']==0)]

# %%
Potential_Exits_1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2011                 0.34             0.39               2
# 2046                 0.84             0.65               2
# 2214                 0.59             0.52               2
# 2352                 0.54             0.73               2
# 2410                 0.58             0.50               2
# 2498                 0.45             0.52               2
# 2723                 0.46             0.64               2
# 2846                 0.74             0.38               2
# 3056                 0.48             0.54               2
# 3114                 0.30             0.64               2
# 3230                 0.91             0.42               2
# 3307                 0.76             0.52               2
# 3890                 0.42             0.56               2
# 4145                 0.54             0.67               2
# 4174                 0.48             0.71               2
# ...

# %% [markdown]
# #Cluster 2

# %%
sns.countplot(x='time_spend_company',data=df_train_new[df_train_new['Cluster']==2],hue='left')

# %%
sns.violinplot(x='left',y='average_montly_hours',data=df_train_new[(df_train_new['Cluster']==2)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='satisfaction_level',data=df_train_new[(df_train_new['Cluster']==2)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sns.violinplot(x='left',y='last_evaluation',data=df_train_new[(df_train_new['Cluster']==2)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Cluster 2 resembles employees who are satisfied and who are rate high on last evaluation. Thus no potential reason to fire them. People who will exit are the ones with experience looking to pursue better opportunities.

# %%
Potential_Exits_2 = df_train_new[(df_train_new['time_spend_company']==5)&(df_train_new['Cluster']==2)&(df_train_new['left']==0)]

# %%
Potential_Exits_2
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2018                 0.89             0.92               4
# 2174                 0.88             0.81               5
# 2176                 0.82             0.73               4
# 2261                 0.83             0.54               4
# 2292                 0.99             0.75               6
# 2415                 0.92             0.97               4
# 2570                 0.80             0.96               3
# 2688                 0.83             0.55               5
# 2703                 0.76             0.93               3
# 2842                 0.73             0.88               5
# 2853                 0.55             0.81               4
# 3079                 0.82             0.97               3
# 3210                 0.70             0.88               3
# 3261                 1.00             0.87               4
# 3326                 0.94             0.97               5
# ...

# %% [markdown]
# Cluster 3 represents employees who are happy and would be retained

# %% [markdown]
# #Experiments on Choosing the right number of clusters

# %% [markdown]
# # Clusters = 6

# %%
kproto_2 = kprototypes.KPrototypes(n_clusters=6, init='Cao', verbose=2)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.

# %%
clusters_2 = kproto_2.fit_predict(X_train_4, categorical=[5,6,7,8])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 4686, ncost: 41306.796513124915
# Run: 1, iteration: 2/100, moves: 1583, ncost: 40717.70628373066
# Run: 1, iteration: 3/100, moves: 552, ncost: 40643.483941703256
# Run: 1, iteration: 4/100, moves: 274, ncost: 40617.719227679925
# Run: 1, iteration: 5/100, moves: 237, ncost: 40595.31843558172
# Run: 1, iteration: 6/100, moves: 200, ncost: 40582.86699329774
# Run: 1, iteration: 7/100, moves: 96, ncost: 40579.55396616369
# Run: 1, iteration: 8/100, moves: 56, ncost: 40578.175647253716
# Run: 1, iteration: 9/100, moves: 53, ncost: 40576.815244594145
# Run: 1, iteration: 10/100, moves: 35, ncost: 40576.24426176452
# Run: 1, iteration: 11/100, moves: 17, ncost: 40576.08795493375
# Run: 1, iteration: 12/100, moves: 13, ncost: 40575.99323806963
# Run: 1, iteration: 13/100, moves: 14, ncost: 40575.88465207972
# Run: 1, iteration: 14/100, moves: 8, ncost: 40575.83819350601
# ...
